# %% [markdown]
# ### Fetch ..

# %%
import os
import sys

sys.path.append(os.path.abspath("/Users/apoltavets/anna-apps/annalyticai/careear-stats/pipeline"))

from legacy.linkedin_client import LinkedinClient
from legacy.data_persistance_client import Datapersistenceclient

client = Datapersistenceclient("/Users/apoltavets/anna-apps/annalyticai/careear-stats/output")
LinkedinClient().load_jobs_by_keywords(start_date='2025-08-26', end_date='2025-08-26', country='US', keyword='software', start_iter=226,persistence=client)
